# %% [markdown]
# # Pokemon EDA

# %% [markdown]
# Dataset from Kaggle.com by Alberto Barradas: https://www.kaggle.com/datasets/abcsds/pokemon

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/Users/vivianchung/Downloads/Pokemon.csv')
# pd.read_excel
# pd.read_cvs('path', delimiter='\t')
df.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
df['Name'][0:5] #.head() works too
# Out:
# 0                Bulbasaur
# 1                  Ivysaur
# 2                 Venusaur
# 3    VenusaurMega Venusaur
# 4               Charmander
# Name: Name, dtype: object

# %%
# print multiple columns, need to put in a list and double brackets
df[['Name', 'Total']]
# Out:
#                       Name  Total
# 0                Bulbasaur    318
# 1                  Ivysaur    405
# 2                 Venusaur    525
# 3    VenusaurMega Venusaur    625
# 4               Charmander    309
# ..                     ...    ...
# 795                Diancie    600
# 796    DiancieMega Diancie    700
# 797    HoopaHoopa Confined    600
# 798     HoopaHoopa Unbound    680
# 799              Volcanion    600
#
# [800 rows x 2 columns]

# %%
#will get all info from rows based on index/integer location
df.iloc[1:4]
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False

# %%
df.iloc[:3, 1]
# df.iloc[ROWS from:to , what columns from:to]
# Out:
# 0    Bulbasaur
# 1      Ivysaur
# 2     Venusaur
# Name: Name, dtype: object

# %%
df.iloc[:5, 1:5]
# Out:
#                     Name Type 1  Type 2  Total
# 0              Bulbasaur  Grass  Poison    318
# 1                Ivysaur  Grass  Poison    405
# 2               Venusaur  Grass  Poison    525
# 3  VenusaurMega Venusaur  Grass  Poison    625
# 4             Charmander   Fire     NaN    309

# %%
df.loc[df['Type 1']=='Fire']
# Out:
#        #                       Name Type 1    Type 2  Total   HP  Attack  \
# 4      4                 Charmander   Fire       NaN    309   39      52
# 5      5                 Charmeleon   Fire       NaN    405   58      64
# 6      6                  Charizard   Fire    Flying    534   78      84
# 7      6  CharizardMega Charizard X   Fire    Dragon    634   78     130
# 8      6  CharizardMega Charizard Y   Fire    Flying    634   78     104
# 42    37                     Vulpix   Fire       NaN    299   38      41
# 43    38                  Ninetales   Fire       NaN    505   73      76
# 63    58                  Growlithe   Fire       NaN    350   55      70
# 64    59                   Arcanine   Fire       NaN    555   90     110
# 83    77                     Ponyta   Fire       NaN    410   50      85
# 84    78                   Rapidash   Fire       NaN    500   65     100
# 135  126                     Magmar   Fire       NaN    495   65      95
# ...

# %%
df.describe()
# Out:
#                 #      Total          HP      Attack     Defense     Sp. Atk  \
# count  800.000000  800.00000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750  435.10250   69.258750   79.001250   73.842500   72.820000
# std    208.343798  119.96304   25.534669   32.457366   31.183501   32.722294
# min      1.000000  180.00000    1.000000    5.000000    5.000000   10.000000
# 25%    184.750000  330.00000   50.000000   55.000000   50.000000   49.750000
# 50%    364.500000  450.00000   65.000000   75.000000   70.000000   65.000000
# 75%    539.250000  515.00000   80.000000  100.000000   90.000000   95.000000
# max    721.000000  780.00000  255.000000  190.000000  230.000000  194.000000
#
#           Sp. Def       Speed  Generation
# count  800.000000  800.000000   800.00000
# mean    71.902500   68.277500     3.32375
# std     27.828916   29.060474     1.66129
# min     20.000000    5.000000     1.00000
# 25%     50.000000   45.000000     2.00000
# ...

# %%
df.sort_values(['Total', 'Type 1'], ascending=[False,False]).head()
# Out:
#        #                   Name   Type 1    Type 2  Total   HP  Attack  \
# 163  150    MewtwoMega Mewtwo X  Psychic  Fighting    780  106     190
# 164  150    MewtwoMega Mewtwo Y  Psychic       NaN    780  106     150
# 426  384  RayquazaMega Rayquaza   Dragon    Flying    780  105     180
# 422  382    KyogrePrimal Kyogre    Water       NaN    770  100     150
# 424  383  GroudonPrimal Groudon   Ground      Fire    770  100     180
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 163      100      154      100    130           1       True
# 164       70      194      120    140           1       True
# 426      100      180      100    115           3       True
# 422       90      180      160     90           3       True
# 424      160      150       90     90           3       True

# %%
df['Sum'] = df['HP'] + df['Attack'] + df['Defense'] + df['Sp. Atk'] + df['Sp. Def'] + df['Speed']

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary  Sum
# 0       65       65     45           1      False  318
# 1       80       80     60           1      False  405
# 2      100      100     80           1      False  525
# 3      122      120     80           1      False  625
# 4       60       50     65           1      False  309

# %%
compare = df['Total'] == df['Sum']

# %%
compare.all()
#Checking All Values: We use the all() method on the boolean Series to check if all values are True.
# Out:
# True

# %%
df = df.drop('Sum', axis=1)
df.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
# df.to_csv(new_name.csv, index=False)
# df.to_excel(new_name.xlsx, index=False)

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
df.loc[ (df['Type 1']=='Grass') & (df['Type 2']=='Poison') & (df['HP']>50) ]
# Out:
#        #                   Name Type 1  Type 2  Total   HP  Attack  Defense  \
# 1      2                Ivysaur  Grass  Poison    405   60      62       63
# 2      3               Venusaur  Grass  Poison    525   80      82       83
# 3      3  VenusaurMega Venusaur  Grass  Poison    625   80     100      123
# 49    44                  Gloom  Grass  Poison    395   60      65       70
# 50    45              Vileplume  Grass  Poison    490   75      80       85
# 76    70             Weepinbell  Grass  Poison    390   65      90       50
# 77    71             Victreebel  Grass  Poison    490   80     105       65
# 452  407               Roserade  Grass  Poison    515   60      70       65
# 651  590                Foongus  Grass  Poison    294   69      55       45
# 652  591              Amoonguss  Grass  Poison    464  114      85       70
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 1         80       80     60           1      False
# ...

# %%
df['Type 1'].unique()
# Out:
# array(['Grass', 'Fire', 'Water', 'Bug', 'Normal', 'Poison', 'Electric',
#        'Ground', 'Fairy', 'Fighting', 'Psychic', 'Rock', 'Ghost', 'Ice',
#        'Dragon', 'Dark', 'Steel', 'Flying'], dtype=object)

# %%
df['Type 2'].unique()
# Out:
# array(['Poison', nan, 'Flying', 'Dragon', 'Ground', 'Fairy', 'Grass',
#        'Fighting', 'Psychic', 'Steel', 'Ice', 'Rock', 'Dark', 'Water',
#        'Electric', 'Fire', 'Ghost', 'Bug', 'Normal'], dtype=object)

# %%
df['Type 1'].nunique()
# Out:
# 18

# %%
df['Type 2'].nunique()
# Out:
# 18

# %%
df.loc[df['Name'].str.contains('Mega'), ['Name', 'Type 1', 'Total']]
#df.loc[~df['Name'].str.contains('Mega'), ['Name', 'Type 1', 'Total']]
# Out:
#                           Name    Type 1  Total
# 3        VenusaurMega Venusaur     Grass    625
# 7    CharizardMega Charizard X      Fire    634
# 8    CharizardMega Charizard Y      Fire    634
# 12     BlastoiseMega Blastoise     Water    630
# 19       BeedrillMega Beedrill       Bug    495
# 23         PidgeotMega Pidgeot    Normal    579
# 71       AlakazamMega Alakazam   Psychic    590
# 87         SlowbroMega Slowbro     Water    590
# 102          GengarMega Gengar     Ghost    600
# 124  KangaskhanMega Kangaskhan    Normal    590
# 137          PinsirMega Pinsir       Bug    600
# 141      GyaradosMega Gyarados     Water    640
# 154  AerodactylMega Aerodactyl      Rock    615
# 163        MewtwoMega Mewtwo X   Psychic    780
# 164        MewtwoMega Mewtwo Y   Psychic    780
# 168                   Meganium     Grass    525
# 196      AmpharosMega Ampharos  Electric    610
# 224        SteelixMega Steelix     Steel    610
# 229          ScizorMega Scizor       Bug    600
# ...

# %%
df[df['Name'].str.contains('Mega')]
# df[~df['Name'].str.contains('Mega')]
# Out:
#        #                       Name    Type 1    Type 2  Total   HP  Attack  \
# 3      3      VenusaurMega Venusaur     Grass    Poison    625   80     100
# 7      6  CharizardMega Charizard X      Fire    Dragon    634   78     130
# 8      6  CharizardMega Charizard Y      Fire    Flying    634   78     104
# 12     9    BlastoiseMega Blastoise     Water       NaN    630   79     103
# 19    15      BeedrillMega Beedrill       Bug    Poison    495   65     150
# 23    18        PidgeotMega Pidgeot    Normal    Flying    579   83      80
# 71    65      AlakazamMega Alakazam   Psychic       NaN    590   55      50
# 87    80        SlowbroMega Slowbro     Water   Psychic    590   95      75
# 102   94          GengarMega Gengar     Ghost    Poison    600   60      65
# 124  115  KangaskhanMega Kangaskhan    Normal       NaN    590  105     125
# 137  127          PinsirMega Pinsir       Bug    Flying    600   65     155
# ...

# %%
#df.loc[df['Type 1']=='Grass', 'Type 1'] = 'Weed'
# you can change multiple columns, just put in list okurrrr

# %%
group1 = df.groupby('Type 1')['Type 1'].count()

# %%
group1 = group1.sort_values(ascending=False).head(10)
group1
# Out:
# Type 1
# Water       112
# Normal       98
# Grass        70
# Bug          69
# Psychic      57
# Fire         52
# Electric     44
# Rock         44
# Ghost        32
# Ground       32
# Name: Type 1, dtype: int64

# %%
color_palette = sns.color_palette('colorblind')

group1.plot(kind='bar', color=color_palette)
plt.title('Top 10 Type 1 Pokemon')
plt.xlabel('Type 1')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.show()

# %%
group2 = df.groupby('Type 2')['Type 2'].count()
group2 = group2.sort_values(ascending=False).head(10)
group2
# Out:
# Type 2
# Flying      97
# Ground      35
# Poison      34
# Psychic     33
# Fighting    26
# Grass       25
# Fairy       23
# Steel       22
# Dark        20
# Dragon      18
# Name: Type 2, dtype: int64

# %%
color_palette = sns.color_palette('colorblind')

group2.plot(kind='bar', color=color_palette)
plt.title('Top 10 Type 2 Pokemon')
plt.xlabel('Type 2')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.show()

# %%
generation = df.groupby('Generation')['Generation'].count().sort_index()

# %%
generation.plot(kind='bar', color = color_palette)
plt.title('Pokemon Count by Generation')
plt.xlabel('Generation')
plt.ylabel('Frequency')
plt.xticks(rotation=0)
plt.show()

# %%
labels = ['Normal Pokemon', 'Legendary Pokemon']

leg.plot(kind='pie', labels = labels, autopct='%1.1f%%')
plt.title('Legendary Pokemon')
plt.ylabel('')
plt.show()

# %%
# Function that groups the Pokemon by Type 1 and looks at the average stats

# Total, HP, Attack, Defense, Sp. Atk, Sp. Def, Speed

def bar_template (var):
    color_palette = sns.color_palette('colorblind')
    avg = round(df.groupby('Type 1')[var].mean()).sort_values(ascending=False).head(10)
    avg.plot(kind='bar', color = color_palette)
    plt.title('Top 10 Pokemon Type 1 with Highest ' + var)
    plt.xlabel('Pokemon Type 1')
    plt.ylabel('Average')
    plt.xticks(rotation=45)
    plt.show()

# %%
bar_template('Sp. Atk')

# %%
# Function that selects the top 10 Pokémon based on a specified variable: 
# Total, HP, Attack, Defense, Sp. Atk, Sp. Def, Speed

def poke_10 (var):
    top_10 = df[['Name', var]].sort_values(by=var, ascending=False).head(10).set_index('Name')
    return(top_10)

# %%
#top_10 = df[['Name', 'Total']].sort_values(by='Total', ascending=False).head(10).set_index('Name')
#top_10

# %%
poke_10('Speed')
# Out:
#                            Speed
# Name
# DeoxysSpeed Forme            180
# Ninjask                      160
# DeoxysNormal Forme           150
# AerodactylMega Aerodactyl    150
# AlakazamMega Alakazam        150
# DeoxysAttack Forme           150
# BeedrillMega Beedrill        145
# SceptileMega Sceptile        145
# Accelgor                     145
# MewtwoMega Mewtwo Y          140
